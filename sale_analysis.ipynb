# %% [markdown]
# <a href="https://colab.research.google.com/github/akhila-stack/sale-analysis/blob/main/sale_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

print(os.getcwd())  # check folder

df = pd.read_csv("/content/sales_data.csv")  # same folder

print(df.head())
print(df.info())

print(df.isnull().sum())

total_sales = df['Sales'].sum()
print("Total Sales:", total_sales)

sales_by_region = df.groupby('Region')['Sales'].sum()
print(sales_by_region)

sales_by_region.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.show()

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Month'] = df['Order Date'].dt.month

daily_sales = df.groupby("Order Date")["Sales"].sum()

daily_sales.plot()
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()
# Out:
# /content
#    Order Date     Product Region  Quantity   Sales
# 0  2024-01-05      Laptop  South         2  120000
# 1  2024-01-08      Mobile  North         5   75000
# 2  2024-01-10      Tablet   East         3   45000
# 3  2024-01-12      Laptop   West         1   60000
# 4  2024-01-15  Headphones  South        10   30000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  10 non-null     object
#  1   Product     10 non-null     object
#  2   Region      10 non-null     object
#  3   Quantity    10 non-null     int64
#  4   Sales       10 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes
# None
# Order Date    0
# Product       0
# Region        0
# Quantity      0
# Sales         0
# dtype: int64
# Total Sales: 648000
# Region
# East     105000
# North    105000
# South    360000
# West      78000
# ...
